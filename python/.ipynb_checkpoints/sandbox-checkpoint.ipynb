# %%
import pandas as pd

# %%
contact = pd.read_csv("results/massive_final_week_contact.csv").drop_duplicates()
display(contact)
# Out:
#     Unnamed: 0  accuracy  N_HIDDEN_LAYERS  N_UNITS  N_FILTERS  KERNEL_SIZE  \
# 0            4  0.873510                2       32         64            4
# 20           1  0.871502                1       32         32            4
# 43           3  0.858881                1       96         32           16
# 64           2  0.854128                2       64         64            8
# 86           6  0.706658                2       64         64            4
#
#                         LOSS ACTIVATION LAST_ACTIVATION  DROPOUT  ...  \
# 0   categorical_crossentropy       tanh         softmax      0.2  ...
# 20  categorical_crossentropy       tanh         softmax      0.2  ...
# 43  categorical_crossentropy       relu         softmax      0.4  ...
# 64  categorical_crossentropy       tanh         softmax      0.4  ...
# 86  categorical_crossentropy       tanh         softmax      0.3  ...
#
#     SHUFFLE STANDARD OVERSAMPLE FFT_ONLY  FFT_ADDED  WHICH_DATA  \
# ...

# %%
radar = pd.read_csv("results/massive_final_week_radar.csv").drop_duplicates()
display(radar)
# Out:
#     Unnamed: 0  accuracy  N_HIDDEN_LAYERS  N_UNITS  N_FILTERS  KERNEL_SIZE  \
# 0            5  0.826429                1       32         96            8
# 5            3  0.816882                1       32         96            8
# 12           2  0.816554                1       32         96            8
# 20           1  0.794591                1       32         96            8
# 29           7  0.789879                1       32         96            8
#
#                         LOSS ACTIVATION LAST_ACTIVATION  DROPOUT  ...  \
# 0   categorical_crossentropy       relu         softmax      0.2  ...
# 5   categorical_crossentropy       relu         softmax      0.2  ...
# 12  categorical_crossentropy       tanh         softmax      0.2  ...
# 20  categorical_crossentropy       relu         softmax      0.3  ...
# 29  categorical_crossentropy       relu         softmax      0.2  ...
#
#     SHUFFLE STANDARD OVERSAMPLE FFT_ONLY  FFT_ADDED  WHICH_DATA  \
# ...

# %%
contact_FFT = pd.read_csv("results/massive_final_week_contact_FFT.csv").drop_duplicates()
display(contact_FFT)
# Out:
#     Unnamed: 0  accuracy  N_HIDDEN_LAYERS  N_UNITS  N_FILTERS  KERNEL_SIZE  \
# 0            0  0.880025                1       32         32            8
# 7            0  0.856997                1       96         32            4
# 18           2  0.588281                1       64         64            8
# 23           1  0.547593                2       32         64            4
# 29           1  0.467076                2       64         96            8
#
#                         LOSS ACTIVATION LAST_ACTIVATION  DROPOUT  ...  \
# 0   categorical_crossentropy       tanh         softmax      0.3  ...
# 7   categorical_crossentropy       tanh         softmax      0.4  ...
# 18  categorical_crossentropy       relu         softmax      0.2  ...
# 23  categorical_crossentropy       relu         softmax      0.2  ...
# 29  categorical_crossentropy       relu         softmax      0.2  ...
#
#     SHUFFLE STANDARD OVERSAMPLE FFT_ONLY  FFT_ADDED  WHICH_DATA  \
# ...

# %%
radar_FFT = pd.read_csv("results/massive_final_week_radar_FFT.csv").drop_duplicates()
display(radar_FFT)
# Out:
#     Unnamed: 0  accuracy  N_HIDDEN_LAYERS  N_UNITS  N_FILTERS  KERNEL_SIZE  \
# 0            0  0.827494                1       64         64            4
# 7            1  0.607908                2       32         64           16
# 13           2  0.253350                2       32         96            4
# 18           4  0.218357                1       96         96           16
# 21           3  0.209711                2       96         96            8
#
#                         LOSS ACTIVATION LAST_ACTIVATION  DROPOUT  ...  \
# 0   categorical_crossentropy       tanh         softmax      0.3  ...
# 7   categorical_crossentropy       tanh         softmax      0.3  ...
# 13  categorical_crossentropy       relu         softmax      0.3  ...
# 18  categorical_crossentropy       tanh         softmax      0.3  ...
# 21  categorical_crossentropy       relu         softmax      0.3  ...
#
#     SHUFFLE STANDARD OVERSAMPLE FFT_ONLY  FFT_ADDED  WHICH_DATA  \
# ...
